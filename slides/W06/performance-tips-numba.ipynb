# %%
from numba import jit
import numpy as np
import time

def go_slow(a):
    trace = 0
    for i in range(a.shape[0]):
        trace += np.tanh(a[i, i])
    return a + trace

go_fast = jit(go_slow, nopython=True)

# %%
x = np.arange(100).reshape(10, 10)
# %timeit go_slow(x)
# Out:
# 45 µs ± 2.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
x = np.arange(100).reshape(10, 10)
go_fast(x)
# %timeit go_fast(x)
# Out:
# 1.42 µs ± 72.9 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
from dis import dis
dis(go_slow)
# Out:
#   6           0 LOAD_CONST               1 (0)
#               2 STORE_FAST               1 (trace)
#
#   7           4 SETUP_LOOP              44 (to 50)
#               6 LOAD_GLOBAL              0 (range)
#               8 LOAD_FAST                0 (a)
#              10 LOAD_ATTR                1 (shape)
#              12 LOAD_CONST               1 (0)
#              14 BINARY_SUBSCR
#              16 CALL_FUNCTION            1
#              18 GET_ITER
#         >>   20 FOR_ITER                26 (to 48)
#              22 STORE_FAST               2 (i)
#
#   8          24 LOAD_FAST                1 (trace)
#              26 LOAD_GLOBAL              2 (np)
#              28 LOAD_METHOD              3 (tanh)
#              30 LOAD_FAST                0 (a)
#              32 LOAD_FAST                2 (i)
#              34 LOAD_FAST                2 (i)
#              36 BUILD_TUPLE              2
#              38 BINARY_SUBSCR
#              40 CALL_METHOD              1
#              42 INPLACE_ADD
#              44 STORE_FAST               1 (trace)
#              46 JUMP_ABSOLUTE           20
#         >>   48 POP_BLOCK
#
#   9     >>   50 LOAD_FAST                0 (a)
#              52 LOAD_FAST                1 (trace)
#              54 BINARY_ADD
#              56 RETURN_VALUE

# %%
for code in go_fast.inspect_llvm().values():
    print(code)
# Out:
# ; ModuleID = 'go_slow'
# source_filename = "<string>"
# target datalayout = "e-m:e-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @"_ZN08NumbaEnv8__main__11go_slow$241E5ArrayIxLi2E1C7mutable7alignedE" = common local_unnamed_addr global i8* null
# @.const.picklebuf.140504373705856 = internal constant { i8*, i32 } { i8* getelementptr inbounds ([137 x i8], [137 x i8]* @.const.pickledata.140504373705856, i32 0, i32 0), i32 137 }
# @.const.pickledata.140504373705856 = internal constant [137 x i8] c"\80\04\95~\00\00\00\00\00\00\00\8C\08builtins\94\8C\0AValueError\94\93\94\8C[array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.\94\85\94N\87\94."
# @.const.go_slow = internal constant [8 x i8] c"go_slow\00"
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment" = internal constant [20 x i8] c"missing Environment\00"
# @PyExc_TypeError = external global i8
# @".const.can't unbox array from PyObject into native value.  The object maybe of a different type" = internal constant [89 x i8] c"can't unbox array from PyObject into native value.  The object maybe of a different type\00"
# @_Py_NoneStruct = external global i8
# @PyExc_StopIteration = external global i8
# @PyExc_SystemError = external global i8
# @".const.unknown error when calling native function" = internal constant [43 x i8] c"unknown error when calling native function\00"
# @"_ZN08NumbaEnv13$3cdynamic$3e37__numba_array_expr_0x7fc9b9588310$242Exd" = common local_unnamed_addr global i8* null
# @"_ZN08NumbaEnv5numba7targets7npyimpl19_broadcast_onto$243Ex8int64$2ax8int64$2a" = common local_unnamed_addr global i8* null
#
# define i32 @"_ZN8__main__11go_slow$241E5ArrayIxLi2E1C7mutable7alignedE"({ i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* noalias nocapture %retptr, { i8*, i32 }** noalias nocapture %excinfo, i8* %arg.a.0, i8* nocapture readnone %arg.a.1, i64 %arg.a.2, i64 %arg.a.3, i64* nocapture readonly %arg.a.4, i64 %arg.a.5.0, i64 %arg.a.5.1, i64 %arg.a.6.0, i64 %arg.a.6.1) local_unnamed_addr {
# entry:
#   tail call void @NRT_incref(i8* %arg.a.0)
#   %.121 = icmp sgt i64 %arg.a.5.0, 0
#   br i1 %.121, label %B24.preheader, label %B88.i.1
#
# B24.preheader:                                    ; preds = %entry
#   %0 = shl i64 %arg.a.5.1, 3
#   %1 = add i64 %0, 8
#   br label %B24
#
# B24:                                              ; preds = %B24.preheader, %B24
#   %lsr.iv181 = phi i64* [ %arg.a.4, %B24.preheader ], [ %2, %B24 ]
#   %trace.087 = phi double [ %.334, %B24 ], [ 0.000000e+00, %B24.preheader ]
#   %.110.085 = phi i64 [ %.182, %B24 ], [ %arg.a.5.0, %B24.preheader ]
#   %lsr.iv181182 = bitcast i64* %lsr.iv181 to i1*
#   %.182 = add nsw i64 %.110.085, -1
#   %.303 = load i64, i64* %lsr.iv181, align 8
#   %.319.le = sitofp i64 %.303 to double
#   %.320.le = tail call double @tanh(double %.319.le)
#   %.334 = fadd double %trace.087, %.320.le
#   %scevgep183 = getelementptr i1, i1* %lsr.iv181182, i64 %1
#   %2 = bitcast i1* %scevgep183 to i64*
#   %.173 = icmp sgt i64 %.182, 0
#   br i1 %.173, label %B24, label %B88.i.1
#
# B52.endif.endif.if:                               ; preds = %B88.i.1
#   store { i8*, i32 }* @.const.picklebuf.140504373705856, { i8*, i32 }** %excinfo, align 8
#   ret i32 1
#
# B52.endif.endif.endif:                            ; preds = %B88.i.1
#   %.430 = shl i64 %arg.a.5.1, 3
#   %.432 = extractvalue { i64, i1 } %.431, 0
#   %.441 = tail call i8* @NRT_MemInfo_alloc_safe_aligned(i64 %.432, i32 32)
#   %.5.i = getelementptr i8, i8* %.441, i64 24
#   %3 = bitcast i8* %.5.i to i8**
#   %.6.i = load i8*, i8** %3, align 8
#   %.48947 = icmp sgt i64 %arg.a.5.0, 0
#   br i1 %.48947, label %for.cond.2.preheader.lr.ph, label %for.end.1
#
# for.cond.2.preheader.lr.ph:                       ; preds = %B52.endif.endif.endif
#   %.49228 = icmp sgt i64 %arg.a.5.1, 0
#   br i1 %.49228, label %for.cond.2.preheader.us.preheader, label %for.end.1
#
# for.cond.2.preheader.us.preheader:                ; preds = %for.cond.2.preheader.lr.ph
#   %4 = shl i64 %arg.a.5.1, 3
#   %5 = shl i64 %arg.a.5.1, 3
#   %6 = add i64 %arg.a.5.1, -1
#   %7 = add i64 %arg.a.5.1, -4
#   %8 = lshr i64 %7, 2
#   %9 = add nuw nsw i64 %8, 1
#   %xtraiter = and i64 %arg.a.5.1, 3
#   %unroll_iter = sub i64 %arg.a.5.1, %xtraiter
#   %n.vec159 = and i64 %arg.a.5.1, -4
#   %broadcast.splatinsert168 = insertelement <4 x double> undef, double %trace.0.lcssa102, i32 0
#   %broadcast.splat169 = shufflevector <4 x double> %broadcast.splatinsert168, <4 x double> undef, <4 x i32> zeroinitializer
#   %xtraiter203 = and i64 %9, 3
#   %ind.escape170 = add i64 %n.vec159, -1
#   %n.vec = and i64 %arg.a.5.1, -4
#   %broadcast.splatinsert113 = insertelement <4 x double> undef, double %trace.0.lcssa102, i32 0
#   %broadcast.splat114 = shufflevector <4 x double> %broadcast.splatinsert113, <4 x double> undef, <4 x i32> zeroinitializer
#   %ind.escape = add i64 %n.vec, -1
#   %scevgep6 = getelementptr i8, i8* %.6.i, i64 24
#   %10 = shl i64 %arg.a.5.1, 3
#   %scevgep38 = getelementptr i64, i64* %arg.a.4, i64 12
#   %11 = add i64 %xtraiter203, -1
#   %12 = sub i64 %11, %8
#   %13 = shl i64 %xtraiter203, 5
#   %14 = sub i64 0, %xtraiter
#   %15 = sub i64 0, %arg.a.5.1
#   %scevgep124 = getelementptr i64, i64* %arg.a.4, i64 12
#   %scevgep160 = getelementptr i64, i64* %arg.a.4, i64 3
#   br label %for.cond.2.preheader.us
#
# for.cond.2.preheader.us:                          ; preds = %for.cond.2.for.end.2_crit_edge.us, %for.cond.2.preheader.us.preheader
#   %lsr.iv68 = phi i64* [ %47, %for.cond.2.for.end.2_crit_edge.us ], [ %arg.a.4, %for.cond.2.preheader.us.preheader ]
#   %lsr.iv55 = phi i64 [ %lsr.iv.next56, %for.cond.2.for.end.2_crit_edge.us ], [ 0, %for.cond.2.preheader.us.preheader ]
#   %lsr.iv39 = phi i64* [ %46, %for.cond.2.for.end.2_crit_edge.us ], [ %scevgep38, %for.cond.2.preheader.us.preheader ]
#   %lsr.iv20 = phi i8* [ %45, %for.cond.2.for.end.2_crit_edge.us ], [ %.6.i, %for.cond.2.preheader.us.preheader ]
#   %lsr.iv = phi i8* [ %44, %for.cond.2.for.end.2_crit_edge.us ], [ %scevgep6, %for.cond.2.preheader.us.preheader ]
#   %loop.index.151.us = phi i64 [ %.544.us, %for.cond.2.for.end.2_crit_edge.us ], [ 0, %for.cond.2.preheader.us.preheader ]
#   %.485.050.us = phi i64 [ %split32.us, %for.cond.2.for.end.2_crit_edge.us ], [ 0, %for.cond.2.preheader.us.preheader ]
#   %.482.048.us = phi i64 [ %split.us, %for.cond.2.for.end.2_crit_edge.us ], [ 0, %for.cond.2.preheader.us.preheader ]
#   %16 = icmp eq i64 %arg.a.5.0, 1
#   %17 = mul i64 %5, %loop.index.151.us
#   %scevgep146 = getelementptr i8, i8* %.6.i, i64 %17
#   %18 = add i64 %5, %17
#   %scevgep147 = getelementptr i8, i8* %.6.i, i64 %18
#   %19 = mul i64 %loop.index.151.us, %arg.a.5.1
#   %scevgep148 = getelementptr i64, i64* %arg.a.4, i64 %19
#   %20 = add i64 %19, %arg.a.5.1
#   %scevgep150 = getelementptr i64, i64* %arg.a.4, i64 %20
#   %21 = mul i64 %4, %loop.index.151.us
#   %scevgep = getelementptr i8, i8* %.6.i, i64 %21
#   %22 = add i64 %4, %21
#   %scevgep109 = getelementptr i8, i8* %.6.i, i64 %22
#   br i1 %16, label %for.body.2.endif.endif.endif.lr.ph.for.body.2.endif.endif.endif.lr.ph.split_crit_edge.us, label %for.body.2.endif.endif.endif.lr.ph.split.us.us
#
# for.body.2.endif.endif.endif.us54:                ; preds = %for.body.2.endif.endif.endif.us54.preheader, %for.body.2.endif.endif.endif.us54
#   %loop.index.231.us55 = phi i64 [ %.542.us64.3, %for.body.2.endif.endif.endif.us54 ], [ 0, %for.body.2.endif.endif.endif.us54.preheader ]
#   %sunkaddr = mul i64 %.508.us57, 8
#   %23 = bitcast i64* %arg.a.4 to i8*
#   %sunkaddr186 = getelementptr i8, i8* %23, i64 %sunkaddr
#   %24 = bitcast i8* %sunkaddr186 to i64*
#   %.510.us59 = load i64, i64* %24, align 8
#   %.14.i.us60 = sitofp i64 %.510.us59 to double
#   %.15.i.us61 = fadd double %trace.0.lcssa102, %.14.i.us60
#   %25 = shl i64 %loop.index.231.us55, 3
#   %scevgep104 = getelementptr i8, i8* %lsr.iv, i64 %25
#   %scevgep104105 = bitcast i8* %scevgep104 to double*
#   %scevgep106 = getelementptr double, double* %scevgep104105, i64 -3
#   store double %.15.i.us61, double* %scevgep106, align 8
#   %.510.us59.1 = load i64, i64* %24, align 8
#   %.14.i.us60.1 = sitofp i64 %.510.us59.1 to double
#   %.15.i.us61.1 = fadd double %trace.0.lcssa102, %.14.i.us60.1
#   %26 = shl i64 %loop.index.231.us55, 3
#   %scevgep101 = getelementptr i8, i8* %lsr.iv, i64 %26
#   %scevgep101102 = bitcast i8* %scevgep101 to double*
#   %scevgep103 = getelementptr double, double* %scevgep101102, i64 -2
#   store double %.15.i.us61.1, double* %scevgep103, align 8
#   %.510.us59.2 = load i64, i64* %24, align 8
#   %.14.i.us60.2 = sitofp i64 %.510.us59.2 to double
#   %.15.i.us61.2 = fadd double %trace.0.lcssa102, %.14.i.us60.2
#   %27 = shl i64 %loop.index.231.us55, 3
#   %scevgep98 = getelementptr i8, i8* %lsr.iv, i64 %27
#   %scevgep9899 = bitcast i8* %scevgep98 to double*
#   %scevgep100 = getelementptr double, double* %scevgep9899, i64 -1
#   store double %.15.i.us61.2, double* %scevgep100, align 8
#   %.510.us59.3 = load i64, i64* %24, align 8
#   %.14.i.us60.3 = sitofp i64 %.510.us59.3 to double
#   %.15.i.us61.3 = fadd double %trace.0.lcssa102, %.14.i.us60.3
#   %28 = shl i64 %loop.index.231.us55, 3
#   %scevgep96 = getelementptr i8, i8* %lsr.iv, i64 %28
#   %scevgep9697 = bitcast i8* %scevgep96 to double*
#   store double %.15.i.us61.3, double* %scevgep9697, align 8
#   %.542.us64.3 = add nuw nsw i64 %loop.index.231.us55, 4
#   %niter214.ncmp.3 = icmp eq i64 %unroll_iter, %.542.us64.3
#   br i1 %niter214.ncmp.3, label %for.cond.2.for.end.2_crit_edge.us.loopexit199.unr-lcssa, label %for.body.2.endif.endif.endif.us54, !llvm.loop !0
#
# for.cond.2.for.end.2_crit_edge.us.loopexit199.unr-lcssa: ; preds = %for.body.2.endif.endif.endif.us54, %for.body.2.endif.endif.endif.lr.ph.split.for.body.2.endif.endif.endif.lr.ph.split.split_crit_edge.us
#   %loop.index.231.us55.unr = phi i64 [ 0, %for.body.2.endif.endif.endif.lr.ph.split.for.body.2.endif.endif.endif.lr.ph.split.split_crit_edge.us ], [ %.542.us64.3, %for.body.2.endif.endif.endif.us54 ]
#   %29 = and i64 %arg.a.5.1, 3
#   %30 = icmp eq i64 %29, 0
#   br i1 %30, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us54.epil.preheader
#
# for.body.2.endif.endif.endif.us54.epil.preheader: ; preds = %for.cond.2.for.end.2_crit_edge.us.loopexit199.unr-lcssa
#   %31 = shl i64 %loop.index.231.us55.unr, 3
#   %scevgep107 = getelementptr i8, i8* %lsr.iv20, i64 %31
#   br label %for.body.2.endif.endif.endif.us54.epil
#
# for.body.2.endif.endif.endif.us54.epil:           ; preds = %for.body.2.endif.endif.endif.us54.epil.preheader, %for.body.2.endif.endif.endif.us54.epil
#   %lsr.iv108 = phi i64 [ 0, %for.body.2.endif.endif.endif.us54.epil.preheader ], [ %lsr.iv.next109, %for.body.2.endif.endif.endif.us54.epil ]
#   %sunkaddr187 = mul i64 %.508.us57, 8
#   %32 = bitcast i64* %arg.a.4 to i8*
#   %sunkaddr188 = getelementptr i8, i8* %32, i64 %sunkaddr187
#   %33 = bitcast i8* %sunkaddr188 to i64*
#   %.510.us59.epil = load i64, i64* %33, align 8
#   %.14.i.us60.epil = sitofp i64 %.510.us59.epil to double
#   %.15.i.us61.epil = fadd double %trace.0.lcssa102, %.14.i.us60.epil
#   %34 = shl i64 %lsr.iv108, 3
#   %scevgep111 = getelementptr i8, i8* %scevgep107, i64 %34
#   %scevgep111112 = bitcast i8* %scevgep111 to double*
#   store double %.15.i.us61.epil, double* %scevgep111112, align 8
#   %lsr.iv.next109 = add nuw nsw i64 %lsr.iv108, 1
#   %epil.iter211.cmp = icmp eq i64 %xtraiter, %lsr.iv.next109
#   br i1 %epil.iter211.cmp, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us54.epil, !llvm.loop !2
#
# for.cond.2.for.end.2_crit_edge.us.loopexit202.unr-lcssa: ; preds = %for.body.2.endif.endif.endif.us.us69, %for.body.2.endif.endif.endif.lr.ph.split.us.for.body.2.endif.endif.endif.lr.ph.split.us.split_crit_edge.us
#   %loop.index.231.us.us70.unr = phi i64 [ 0, %for.body.2.endif.endif.endif.lr.ph.split.us.for.body.2.endif.endif.endif.lr.ph.split.us.split_crit_edge.us ], [ %.542.us.us78.3, %for.body.2.endif.endif.endif.us.us69 ]
#   %35 = icmp eq i64 %xtraiter, 0
#   br i1 %35, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us.us69.epil.preheader
#
# for.body.2.endif.endif.endif.us.us69.epil.preheader: ; preds = %for.cond.2.for.end.2_crit_edge.us.loopexit202.unr-lcssa
#   %36 = shl i64 %loop.index.231.us.us70.unr, 3
#   %scevgep23 = getelementptr i8, i8* %lsr.iv20, i64 %36
#   br label %for.body.2.endif.endif.endif.us.us69.epil
#
# for.body.2.endif.endif.endif.us.us69.epil:        ; preds = %for.body.2.endif.endif.endif.us.us69.epil.preheader, %for.body.2.endif.endif.endif.us.us69.epil
#   %lsr.iv24 = phi i64 [ 0, %for.body.2.endif.endif.endif.us.us69.epil.preheader ], [ %lsr.iv.next, %for.body.2.endif.endif.endif.us.us69.epil ]
#   %sunkaddr189 = mul i64 %.508.us.us71, 8
#   %37 = bitcast i64* %arg.a.4 to i8*
#   %sunkaddr190 = getelementptr i8, i8* %37, i64 %sunkaddr189
#   %38 = bitcast i8* %sunkaddr190 to i64*
#   %.510.us.us73.epil = load i64, i64* %38, align 8
#   %.14.i.us.us74.epil = sitofp i64 %.510.us.us73.epil to double
#   %.15.i.us.us75.epil = fadd double %trace.0.lcssa102, %.14.i.us.us74.epil
#   %39 = shl i64 %lsr.iv24, 3
#   %scevgep25 = getelementptr i8, i8* %scevgep23, i64 %39
#   %scevgep2526 = bitcast i8* %scevgep25 to double*
#   store double %.15.i.us.us75.epil, double* %scevgep2526, align 8
#   %lsr.iv.next = add nuw nsw i64 %lsr.iv24, 1
#   %epil.iter.cmp = icmp eq i64 %xtraiter, %lsr.iv.next
#   br i1 %epil.iter.cmp, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us.us69.epil, !llvm.loop !4
#
# for.cond.2.for.end.2_crit_edge.us:                ; preds = %for.body.2.endif.endif.endif.us33.us.prol.loopexit, %middle.block, %for.body.2.endif.endif.endif.us.us69.epil, %for.body.2.endif.endif.endif.us.us.us, %for.body.2.endif.endif.endif.us54.epil, %for.body.2.endif.endif.endif.us33.us, %for.cond.2.for.end.2_crit_edge.us.loopexit199.unr-lcssa, %middle.block142, %for.body.2.endif.endif.endif.us.us.us.prol.loopexit, %for.cond.2.for.end.2_crit_edge.us.loopexit202.unr-lcssa
#   %split.us = phi i64 [ %loop.index.151.us, %middle.block142 ], [ %loop.index.151.us, %for.body.2.endif.endif.endif.us.us.us.prol.loopexit ], [ %loop.index.151.us, %for.cond.2.for.end.2_crit_edge.us.loopexit202.unr-lcssa ], [ %.482.048.us, %for.cond.2.for.end.2_crit_edge.us.loopexit199.unr-lcssa ], [ %.482.048.us, %for.body.2.endif.endif.endif.us33.us ], [ %.482.048.us, %for.body.2.endif.endif.endif.us54.epil ], [ %loop.index.151.us, %for.body.2.endif.endif.endif.us.us.us ], [ %loop.index.151.us, %for.body.2.endif.endif.endif.us.us69.epil ], [ %.482.048.us, %middle.block ], [ %.482.048.us, %for.body.2.endif.endif.endif.us33.us.prol.loopexit ]
#   %split32.us = phi i64 [ %ind.escape170, %middle.block142 ], [ %loop.index.231.us.us.us.lcssa.unr, %for.body.2.endif.endif.endif.us.us.us.prol.loopexit ], [ %.485.050.us, %for.cond.2.for.end.2_crit_edge.us.loopexit202.unr-lcssa ], [ %.485.050.us, %for.cond.2.for.end.2_crit_edge.us.loopexit199.unr-lcssa ], [ %lsr.iv.next159, %for.body.2.endif.endif.endif.us33.us ], [ %.485.050.us, %for.body.2.endif.endif.endif.us54.epil ], [ %lsr.iv.next75, %for.body.2.endif.endif.endif.us.us.us ], [ %.485.050.us, %for.body.2.endif.endif.endif.us.us69.epil ], [ %ind.escape, %middle.block ], [ %loop.index.231.us34.us.lcssa.unr, %for.body.2.endif.endif.endif.us33.us.prol.loopexit ]
#   %40 = bitcast i8* %lsr.iv to i1*
#   %41 = bitcast i8* %lsr.iv20 to i1*
#   %42 = bitcast i64* %lsr.iv39 to i1*
#   %43 = bitcast i64* %lsr.iv68 to i1*
#   %.544.us = add nuw nsw i64 %loop.index.151.us, 1
#   %scevgep8 = getelementptr i1, i1* %40, i64 %10
#   %44 = bitcast i1* %scevgep8 to i8*
#   %scevgep22 = getelementptr i1, i1* %41, i64 %10
#   %45 = bitcast i1* %scevgep22 to i8*
#   %scevgep41 = getelementptr i1, i1* %42, i64 %10
#   %46 = bitcast i1* %scevgep41 to i64*
#   %lsr.iv.next56 = add i64 %lsr.iv55, %arg.a.5.1
#   %scevgep70 = getelementptr i1, i1* %43, i64 %10
#   %47 = bitcast i1* %scevgep70 to i64*
#   %exitcond96 = icmp eq i64 %.544.us, %arg.a.5.0
#   br i1 %exitcond96, label %for.end.1, label %for.cond.2.preheader.us
#
# for.body.2.endif.endif.endif.us.us69:             ; preds = %for.body.2.endif.endif.endif.us.us69.preheader, %for.body.2.endif.endif.endif.us.us69
#   %loop.index.231.us.us70 = phi i64 [ %.542.us.us78.3, %for.body.2.endif.endif.endif.us.us69 ], [ 0, %for.body.2.endif.endif.endif.us.us69.preheader ]
#   %sunkaddr191 = mul i64 %.508.us.us71, 8
#   %48 = bitcast i64* %arg.a.4 to i8*
#   %sunkaddr192 = getelementptr i8, i8* %48, i64 %sunkaddr191
#   %49 = bitcast i8* %sunkaddr192 to i64*
#   %.510.us.us73 = load i64, i64* %49, align 8
#   %.14.i.us.us74 = sitofp i64 %.510.us.us73 to double
#   %.15.i.us.us75 = fadd double %trace.0.lcssa102, %.14.i.us.us74
#   %50 = shl i64 %loop.index.231.us.us70, 3
#   %scevgep17 = getelementptr i8, i8* %lsr.iv, i64 %50
#   %scevgep1718 = bitcast i8* %scevgep17 to double*
#   %scevgep19 = getelementptr double, double* %scevgep1718, i64 -3
#   store double %.15.i.us.us75, double* %scevgep19, align 8
#   %.510.us.us73.1 = load i64, i64* %49, align 8
#   %.14.i.us.us74.1 = sitofp i64 %.510.us.us73.1 to double
#   %.15.i.us.us75.1 = fadd double %trace.0.lcssa102, %.14.i.us.us74.1
#   %51 = shl i64 %loop.index.231.us.us70, 3
#   %scevgep14 = getelementptr i8, i8* %lsr.iv, i64 %51
#   %scevgep1415 = bitcast i8* %scevgep14 to double*
#   %scevgep16 = getelementptr double, double* %scevgep1415, i64 -2
#   store double %.15.i.us.us75.1, double* %scevgep16, align 8
#   %.510.us.us73.2 = load i64, i64* %49, align 8
#   %.14.i.us.us74.2 = sitofp i64 %.510.us.us73.2 to double
#   %.15.i.us.us75.2 = fadd double %trace.0.lcssa102, %.14.i.us.us74.2
#   %52 = shl i64 %loop.index.231.us.us70, 3
#   %scevgep11 = getelementptr i8, i8* %lsr.iv, i64 %52
#   %scevgep1112 = bitcast i8* %scevgep11 to double*
#   %scevgep13 = getelementptr double, double* %scevgep1112, i64 -1
#   store double %.15.i.us.us75.2, double* %scevgep13, align 8
#   %.510.us.us73.3 = load i64, i64* %49, align 8
#   %.14.i.us.us74.3 = sitofp i64 %.510.us.us73.3 to double
#   %.15.i.us.us75.3 = fadd double %trace.0.lcssa102, %.14.i.us.us74.3
#   %53 = shl i64 %loop.index.231.us.us70, 3
#   %scevgep9 = getelementptr i8, i8* %lsr.iv, i64 %53
#   %scevgep910 = bitcast i8* %scevgep9 to double*
#   store double %.15.i.us.us75.3, double* %scevgep910, align 8
#   %.542.us.us78.3 = add nuw nsw i64 %loop.index.231.us.us70, 4
#   %niter.ncmp.3 = icmp eq i64 %unroll_iter, %.542.us.us78.3
#   br i1 %niter.ncmp.3, label %for.cond.2.for.end.2_crit_edge.us.loopexit202.unr-lcssa, label %for.body.2.endif.endif.endif.us.us69, !llvm.loop !5
#
# for.body.2.endif.endif.endif.lr.ph.split.us.us:   ; preds = %for.cond.2.preheader.us
#   %54 = icmp ugt i64 %arg.a.5.1, 1
#   %.505.us.us = mul i64 %loop.index.151.us, %arg.a.5.1
#   br i1 %54, label %for.body.2.endif.endif.endif.us.us.us.preheader, label %for.body.2.endif.endif.endif.lr.ph.split.us.for.body.2.endif.endif.endif.lr.ph.split.us.split_crit_edge.us
#
# for.body.2.endif.endif.endif.us.us.us.preheader:  ; preds = %for.body.2.endif.endif.endif.lr.ph.split.us.us
#   %55 = icmp ult i64 %arg.a.5.1, 4
#   br i1 %55, label %for.body.2.endif.endif.endif.us.us.us.preheader200, label %vector.memcheck156
#
# for.body.2.endif.endif.endif.us.us.us.preheader200: ; preds = %middle.block142, %vector.memcheck156, %for.body.2.endif.endif.endif.us.us.us.preheader
#   %loop.index.231.us.us.us.ph = phi i64 [ 0, %vector.memcheck156 ], [ 0, %for.body.2.endif.endif.endif.us.us.us.preheader ], [ %n.vec159, %middle.block142 ]
#   %56 = and i64 %arg.a.5.1, 3
#   %57 = icmp eq i64 %56, 0
#   %58 = xor i64 %loop.index.231.us.us.us.ph, -1
#   %59 = add i64 %58, %arg.a.5.1
#   br i1 %57, label %for.body.2.endif.endif.endif.us.us.us.prol.loopexit, label %for.body.2.endif.endif.endif.us.us.us.prol.preheader
#
# for.body.2.endif.endif.endif.us.us.us.prol.preheader: ; preds = %for.body.2.endif.endif.endif.us.us.us.preheader200
#   br label %for.body.2.endif.endif.endif.us.us.us.prol
#
# for.body.2.endif.endif.endif.us.us.us.prol:       ; preds = %for.body.2.endif.endif.endif.us.us.us.prol.preheader, %for.body.2.endif.endif.endif.us.us.us.prol
#   %lsr.iv72 = phi i64 [ %14, %for.body.2.endif.endif.endif.us.us.us.prol.preheader ], [ %lsr.iv.next73, %for.body.2.endif.endif.endif.us.us.us.prol ]
#   %loop.index.231.us.us.us.prol = phi i64 [ %.542.us.us.us.prol, %for.body.2.endif.endif.endif.us.us.us.prol ], [ %loop.index.231.us.us.us.ph, %for.body.2.endif.endif.endif.us.us.us.prol.preheader ]
#   %scevgep71 = getelementptr i64, i64* %lsr.iv68, i64 %loop.index.231.us.us.us.prol
#   %.510.us.us.us.prol = load i64, i64* %scevgep71, align 8
#   %.14.i.us.us.us.prol = sitofp i64 %.510.us.us.us.prol to double
#   %.15.i.us.us.us.prol = fadd double %trace.0.lcssa102, %.14.i.us.us.us.prol
#   %60 = shl i64 %loop.index.231.us.us.us.prol, 3
#   %scevgep66 = getelementptr i8, i8* %lsr.iv20, i64 %60
#   %scevgep6667 = bitcast i8* %scevgep66 to double*
#   store double %.15.i.us.us.us.prol, double* %scevgep6667, align 8
#   %.542.us.us.us.prol = add nuw nsw i64 %loop.index.231.us.us.us.prol, 1
#   %lsr.iv.next73 = add nsw i64 %lsr.iv72, 1
#   %prol.iter.cmp = icmp eq i64 %lsr.iv.next73, 0
#   br i1 %prol.iter.cmp, label %for.body.2.endif.endif.endif.us.us.us.prol.loopexit.loopexit, label %for.body.2.endif.endif.endif.us.us.us.prol, !llvm.loop !6
#
# for.body.2.endif.endif.endif.us.us.us.prol.loopexit.loopexit: ; preds = %for.body.2.endif.endif.endif.us.us.us.prol
#   %61 = add i64 %.542.us.us.us.prol, -1
#   br label %for.body.2.endif.endif.endif.us.us.us.prol.loopexit
#
# for.body.2.endif.endif.endif.us.us.us.prol.loopexit: ; preds = %for.body.2.endif.endif.endif.us.us.us.prol.loopexit.loopexit, %for.body.2.endif.endif.endif.us.us.us.preheader200
#   %loop.index.231.us.us.us.lcssa.unr = phi i64 [ undef, %for.body.2.endif.endif.endif.us.us.us.preheader200 ], [ %61, %for.body.2.endif.endif.endif.us.us.us.prol.loopexit.loopexit ]
#   %loop.index.231.us.us.us.unr = phi i64 [ %loop.index.231.us.us.us.ph, %for.body.2.endif.endif.endif.us.us.us.preheader200 ], [ %.542.us.us.us.prol, %for.body.2.endif.endif.endif.us.us.us.prol.loopexit.loopexit ]
#   %62 = icmp ult i64 %59, 3
#   br i1 %62, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us.us.us.preheader3
#
# for.body.2.endif.endif.endif.us.us.us.preheader3: ; preds = %for.body.2.endif.endif.endif.us.us.us.prol.loopexit
#   %63 = add i64 %loop.index.231.us.us.us.unr, -1
#   br label %for.body.2.endif.endif.endif.us.us.us
#
# vector.memcheck156:                               ; preds = %for.body.2.endif.endif.endif.us.us.us.preheader
#   %64 = bitcast i64* %scevgep150 to i8*
#   %65 = bitcast i64* %scevgep148 to i8*
#   %bound0152 = icmp ult i8* %scevgep146, %64
#   %bound1153 = icmp ugt i8* %scevgep147, %65
#   %found.conflict154 = and i1 %bound0152, %bound1153
#   br i1 %found.conflict154, label %for.body.2.endif.endif.endif.us.us.us.preheader200, label %vector.ph157
#
# vector.ph157:                                     ; preds = %vector.memcheck156
#   %66 = icmp ult i64 %7, 12
#   br i1 %66, label %middle.block142.unr-lcssa, label %vector.body141.preheader
#
# vector.body141.preheader:                         ; preds = %vector.ph157
#   br label %vector.body141
#
# vector.body141:                                   ; preds = %vector.body141.preheader, %vector.body141
#   %lsr.iv53 = phi i64 [ %12, %vector.body141.preheader ], [ %lsr.iv.next54, %vector.body141 ]
#   %index160 = phi i64 [ %index.next161.3, %vector.body141 ], [ 0, %vector.body141.preheader ]
#   %scevgep50 = getelementptr i64, i64* %lsr.iv39, i64 %index160
#   %scevgep5051 = bitcast i64* %scevgep50 to <4 x i64>*
#   %scevgep52 = getelementptr <4 x i64>, <4 x i64>* %scevgep5051, i64 -3
#   %wide.load167 = load <4 x i64>, <4 x i64>* %scevgep52, align 8, !alias.scope !7
#   %67 = sitofp <4 x i64> %wide.load167 to <4 x double>
#   %68 = fadd <4 x double> %broadcast.splat169, %67
#   %69 = shl i64 %index160, 3
#   %scevgep36 = getelementptr i8, i8* %lsr.iv20, i64 %69
#   %scevgep3637 = bitcast i8* %scevgep36 to <4 x double>*
#   store <4 x double> %68, <4 x double>* %scevgep3637, align 8, !alias.scope !10, !noalias !7
#   %scevgep47 = getelementptr i64, i64* %lsr.iv39, i64 %index160
#   %scevgep4748 = bitcast i64* %scevgep47 to <4 x i64>*
#   %scevgep49 = getelementptr <4 x i64>, <4 x i64>* %scevgep4748, i64 -2
#   %wide.load167.1 = load <4 x i64>, <4 x i64>* %scevgep49, align 8, !alias.scope !7
#   %70 = sitofp <4 x i64> %wide.load167.1 to <4 x double>
#   %71 = fadd <4 x double> %broadcast.splat169, %70
#   %72 = shl i64 %index160, 3
#   %scevgep33 = getelementptr i8, i8* %lsr.iv20, i64 %72
#   %scevgep3334 = bitcast i8* %scevgep33 to <4 x double>*
#   %scevgep35 = getelementptr <4 x double>, <4 x double>* %scevgep3334, i64 1
#   store <4 x double> %71, <4 x double>* %scevgep35, align 8, !alias.scope !10, !noalias !7
#   %scevgep44 = getelementptr i64, i64* %lsr.iv39, i64 %index160
#   %scevgep4445 = bitcast i64* %scevgep44 to <4 x i64>*
#   %scevgep46 = getelementptr <4 x i64>, <4 x i64>* %scevgep4445, i64 -1
#   %wide.load167.2 = load <4 x i64>, <4 x i64>* %scevgep46, align 8, !alias.scope !7
#   %73 = sitofp <4 x i64> %wide.load167.2 to <4 x double>
#   %74 = fadd <4 x double> %broadcast.splat169, %73
#   %75 = shl i64 %index160, 3
#   %scevgep30 = getelementptr i8, i8* %lsr.iv20, i64 %75
#   %scevgep3031 = bitcast i8* %scevgep30 to <4 x double>*
#   %scevgep32 = getelementptr <4 x double>, <4 x double>* %scevgep3031, i64 2
#   store <4 x double> %74, <4 x double>* %scevgep32, align 8, !alias.scope !10, !noalias !7
#   %scevgep42 = getelementptr i64, i64* %lsr.iv39, i64 %index160
#   %scevgep4243 = bitcast i64* %scevgep42 to <4 x i64>*
#   %wide.load167.3 = load <4 x i64>, <4 x i64>* %scevgep4243, align 8, !alias.scope !7
#   %76 = sitofp <4 x i64> %wide.load167.3 to <4 x double>
#   %77 = fadd <4 x double> %broadcast.splat169, %76
#   %78 = shl i64 %index160, 3
#   %scevgep27 = getelementptr i8, i8* %lsr.iv20, i64 %78
#   %scevgep2728 = bitcast i8* %scevgep27 to <4 x double>*
#   %scevgep29 = getelementptr <4 x double>, <4 x double>* %scevgep2728, i64 3
#   store <4 x double> %77, <4 x double>* %scevgep29, align 8, !alias.scope !10, !noalias !7
#   %index.next161.3 = add i64 %index160, 16
#   %lsr.iv.next54 = add i64 %lsr.iv53, 4
#   %niter207.ncmp.3 = icmp eq i64 %lsr.iv.next54, 0
#   br i1 %niter207.ncmp.3, label %middle.block142.unr-lcssa, label %vector.body141, !llvm.loop !12
#
# middle.block142.unr-lcssa:                        ; preds = %vector.body141, %vector.ph157
#   %index160.unr = phi i64 [ 0, %vector.ph157 ], [ %index.next161.3, %vector.body141 ]
#   %79 = icmp eq i64 %xtraiter203, 0
#   br i1 %79, label %middle.block142, label %vector.body141.epil.preheader
#
# vector.body141.epil.preheader:                    ; preds = %middle.block142.unr-lcssa
#   %80 = add i64 %index160.unr, %lsr.iv55
#   %81 = shl i64 %80, 3
#   %scevgep57 = getelementptr i8, i8* %.6.i, i64 %81
#   %scevgep62 = getelementptr i64, i64* %arg.a.4, i64 %80
#   br label %vector.body141.epil
#
# vector.body141.epil:                              ; preds = %vector.body141.epil.preheader, %vector.body141.epil
#   %lsr.iv58 = phi i64 [ 0, %vector.body141.epil.preheader ], [ %lsr.iv.next59, %vector.body141.epil ]
#   %82 = bitcast i64* %scevgep62 to i8*
#   %uglygep64 = getelementptr i8, i8* %82, i64 %lsr.iv58
#   %uglygep6465 = bitcast i8* %uglygep64 to <4 x i64>*
#   %wide.load167.epil = load <4 x i64>, <4 x i64>* %uglygep6465, align 8, !alias.scope !7
#   %83 = sitofp <4 x i64> %wide.load167.epil to <4 x double>
#   %84 = fadd <4 x double> %broadcast.splat169, %83
#   %scevgep60 = getelementptr i8, i8* %scevgep57, i64 %lsr.iv58
#   %scevgep6061 = bitcast i8* %scevgep60 to <4 x double>*
#   store <4 x double> %84, <4 x double>* %scevgep6061, align 8, !alias.scope !10, !noalias !7
#   %lsr.iv.next59 = add nuw nsw i64 %lsr.iv58, 32
#   %epil.iter204.cmp = icmp eq i64 %13, %lsr.iv.next59
#   br i1 %epil.iter204.cmp, label %middle.block142, label %vector.body141.epil, !llvm.loop !13
#
# middle.block142:                                  ; preds = %vector.body141.epil, %middle.block142.unr-lcssa
#   %85 = icmp eq i64 %n.vec159, %arg.a.5.1
#   br i1 %85, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us.us.us.preheader200
#
# for.body.2.endif.endif.endif.lr.ph.for.body.2.endif.endif.endif.lr.ph.split_crit_edge.us: ; preds = %for.cond.2.preheader.us
#   %86 = icmp ugt i64 %arg.a.5.1, 1
#   %.505.us37.us = mul i64 %.482.048.us, %arg.a.5.1
#   br i1 %86, label %for.body.2.endif.endif.endif.us33.us.preheader, label %for.body.2.endif.endif.endif.lr.ph.split.for.body.2.endif.endif.endif.lr.ph.split.split_crit_edge.us
#
# for.body.2.endif.endif.endif.us33.us.preheader:   ; preds = %for.body.2.endif.endif.endif.lr.ph.for.body.2.endif.endif.endif.lr.ph.split_crit_edge.us
#   %87 = icmp ult i64 %arg.a.5.1, 4
#   br i1 %87, label %for.body.2.endif.endif.endif.us33.us.preheader198, label %vector.memcheck
#
# vector.memcheck:                                  ; preds = %for.body.2.endif.endif.endif.us33.us.preheader
#   %88 = bitcast i64* %arg.a.4 to i8*
#   %scevgep110 = getelementptr i64, i64* %arg.a.4, i64 %.505.us37.us
#   %scevgep110111 = bitcast i64* %scevgep110 to i8*
#   %89 = shl i64 %.482.048.us, 3
#   %90 = add i64 %89, 8
#   %91 = mul i64 %90, %arg.a.5.1
#   %uglygep = getelementptr i8, i8* %88, i64 %91
#   %bound0 = icmp ult i8* %scevgep, %uglygep
#   %bound1 = icmp ugt i8* %scevgep109, %scevgep110111
#   %found.conflict = and i1 %bound0, %bound1
#   br i1 %found.conflict, label %for.body.2.endif.endif.endif.us33.us.preheader198, label %vector.ph
#
# vector.ph:                                        ; preds = %vector.memcheck
#   %92 = icmp ult i64 %7, 12
#   br i1 %92, label %middle.block.unr-lcssa, label %vector.body.preheader
#
# vector.body.preheader:                            ; preds = %vector.ph
#   %scevgep125 = getelementptr i64, i64* %scevgep124, i64 %.505.us37.us
#   br label %vector.body
#
# vector.body:                                      ; preds = %vector.body.preheader, %vector.body
#   %lsr.iv137 = phi i64 [ %12, %vector.body.preheader ], [ %lsr.iv.next138, %vector.body ]
#   %index = phi i64 [ %index.next.3, %vector.body ], [ 0, %vector.body.preheader ]
#   %scevgep134 = getelementptr i64, i64* %scevgep125, i64 %index
#   %scevgep134135 = bitcast i64* %scevgep134 to <4 x i64>*
#   %scevgep136 = getelementptr <4 x i64>, <4 x i64>* %scevgep134135, i64 -3
#   %wide.load = load <4 x i64>, <4 x i64>* %scevgep136, align 8, !alias.scope !14
#   %93 = sitofp <4 x i64> %wide.load to <4 x double>
#   %94 = fadd <4 x double> %broadcast.splat114, %93
#   %95 = shl i64 %index, 3
#   %scevgep122 = getelementptr i8, i8* %lsr.iv20, i64 %95
#   %scevgep122123 = bitcast i8* %scevgep122 to <4 x double>*
#   store <4 x double> %94, <4 x double>* %scevgep122123, align 8, !alias.scope !17, !noalias !14
#   %scevgep131 = getelementptr i64, i64* %scevgep125, i64 %index
#   %scevgep131132 = bitcast i64* %scevgep131 to <4 x i64>*
#   %scevgep133 = getelementptr <4 x i64>, <4 x i64>* %scevgep131132, i64 -2
#   %wide.load.1 = load <4 x i64>, <4 x i64>* %scevgep133, align 8, !alias.scope !14
#   %96 = sitofp <4 x i64> %wide.load.1 to <4 x double>
#   %97 = fadd <4 x double> %broadcast.splat114, %96
#   %98 = shl i64 %index, 3
#   %scevgep119 = getelementptr i8, i8* %lsr.iv20, i64 %98
#   %scevgep119120 = bitcast i8* %scevgep119 to <4 x double>*
#   %scevgep121 = getelementptr <4 x double>, <4 x double>* %scevgep119120, i64 1
#   store <4 x double> %97, <4 x double>* %scevgep121, align 8, !alias.scope !17, !noalias !14
#   %scevgep128 = getelementptr i64, i64* %scevgep125, i64 %index
#   %scevgep128129 = bitcast i64* %scevgep128 to <4 x i64>*
#   %scevgep130 = getelementptr <4 x i64>, <4 x i64>* %scevgep128129, i64 -1
#   %wide.load.2 = load <4 x i64>, <4 x i64>* %scevgep130, align 8, !alias.scope !14
#   %99 = sitofp <4 x i64> %wide.load.2 to <4 x double>
#   %100 = fadd <4 x double> %broadcast.splat114, %99
#   %101 = shl i64 %index, 3
#   %scevgep116 = getelementptr i8, i8* %lsr.iv20, i64 %101
#   %scevgep116117 = bitcast i8* %scevgep116 to <4 x double>*
#   %scevgep118 = getelementptr <4 x double>, <4 x double>* %scevgep116117, i64 2
#   store <4 x double> %100, <4 x double>* %scevgep118, align 8, !alias.scope !17, !noalias !14
#   %scevgep126 = getelementptr i64, i64* %scevgep125, i64 %index
#   %scevgep126127 = bitcast i64* %scevgep126 to <4 x i64>*
#   %wide.load.3 = load <4 x i64>, <4 x i64>* %scevgep126127, align 8, !alias.scope !14
#   %102 = sitofp <4 x i64> %wide.load.3 to <4 x double>
#   %103 = fadd <4 x double> %broadcast.splat114, %102
#   %104 = shl i64 %index, 3
#   %scevgep113 = getelementptr i8, i8* %lsr.iv20, i64 %104
#   %scevgep113114 = bitcast i8* %scevgep113 to <4 x double>*
#   %scevgep115 = getelementptr <4 x double>, <4 x double>* %scevgep113114, i64 3
#   store <4 x double> %103, <4 x double>* %scevgep115, align 8, !alias.scope !17, !noalias !14
#   %index.next.3 = add i64 %index, 16
#   %lsr.iv.next138 = add i64 %lsr.iv137, 4
#   %niter219.ncmp.3 = icmp eq i64 %lsr.iv.next138, 0
#   br i1 %niter219.ncmp.3, label %middle.block.unr-lcssa, label %vector.body, !llvm.loop !19
#
# middle.block.unr-lcssa:                           ; preds = %vector.body, %vector.ph
#   %index.unr = phi i64 [ 0, %vector.ph ], [ %index.next.3, %vector.body ]
#   %105 = and i64 %9, 3
#   %106 = icmp eq i64 %105, 0
#   br i1 %106, label %middle.block, label %vector.body.epil.preheader
#
# vector.body.epil.preheader:                       ; preds = %middle.block.unr-lcssa
#   %107 = shl i64 %index.unr, 3
#   %scevgep139 = getelementptr i8, i8* %lsr.iv20, i64 %107
#   %108 = add i64 %index.unr, %.505.us37.us
#   %scevgep144 = getelementptr i64, i64* %arg.a.4, i64 %108
#   br label %vector.body.epil
#
# vector.body.epil:                                 ; preds = %vector.body.epil.preheader, %vector.body.epil
#   %lsr.iv140 = phi i64 [ 0, %vector.body.epil.preheader ], [ %lsr.iv.next141, %vector.body.epil ]
#   %109 = bitcast i64* %scevgep144 to i8*
#   %uglygep146 = getelementptr i8, i8* %109, i64 %lsr.iv140
#   %uglygep146147 = bitcast i8* %uglygep146 to <4 x i64>*
#   %wide.load.epil = load <4 x i64>, <4 x i64>* %uglygep146147, align 8, !alias.scope !14
#   %110 = sitofp <4 x i64> %wide.load.epil to <4 x double>
#   %111 = fadd <4 x double> %broadcast.splat114, %110
#   %scevgep142 = getelementptr i8, i8* %scevgep139, i64 %lsr.iv140
#   %scevgep142143 = bitcast i8* %scevgep142 to <4 x double>*
#   store <4 x double> %111, <4 x double>* %scevgep142143, align 8, !alias.scope !17, !noalias !14
#   %lsr.iv.next141 = add nuw nsw i64 %lsr.iv140, 32
#   %epil.iter216.cmp = icmp eq i64 %13, %lsr.iv.next141
#   br i1 %epil.iter216.cmp, label %middle.block, label %vector.body.epil, !llvm.loop !20
#
# middle.block:                                     ; preds = %vector.body.epil, %middle.block.unr-lcssa
#   %112 = icmp eq i64 %n.vec, %arg.a.5.1
#   br i1 %112, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us33.us.preheader198
#
# for.body.2.endif.endif.endif.us33.us.preheader198: ; preds = %middle.block, %vector.memcheck, %for.body.2.endif.endif.endif.us33.us.preheader
#   %loop.index.231.us34.us.ph = phi i64 [ 0, %vector.memcheck ], [ 0, %for.body.2.endif.endif.endif.us33.us.preheader ], [ %n.vec, %middle.block ]
#   %113 = and i64 %arg.a.5.1, 3
#   %114 = icmp eq i64 %113, 0
#   %115 = xor i64 %loop.index.231.us34.us.ph, -1
#   %116 = add i64 %115, %arg.a.5.1
#   br i1 %114, label %for.body.2.endif.endif.endif.us33.us.prol.loopexit, label %for.body.2.endif.endif.endif.us33.us.prol.preheader
#
# for.body.2.endif.endif.endif.us33.us.prol.preheader: ; preds = %for.body.2.endif.endif.endif.us33.us.preheader198
#   %117 = shl i64 %loop.index.231.us34.us.ph, 3
#   %scevgep154 = getelementptr i64, i64* %arg.a.4, i64 %.505.us37.us
#   br label %for.body.2.endif.endif.endif.us33.us.prol
#
# for.body.2.endif.endif.endif.us33.us.prol:        ; preds = %for.body.2.endif.endif.endif.us33.us.prol.preheader, %for.body.2.endif.endif.endif.us33.us.prol
#   %lsr.iv150 = phi i64 [ %117, %for.body.2.endif.endif.endif.us33.us.prol.preheader ], [ %lsr.iv.next151, %for.body.2.endif.endif.endif.us33.us.prol ]
#   %lsr.iv148 = phi i64 [ 0, %for.body.2.endif.endif.endif.us33.us.prol.preheader ], [ %lsr.iv.next149, %for.body.2.endif.endif.endif.us33.us.prol ]
#   %118 = bitcast i64* %scevgep154 to i8*
#   %uglygep156 = getelementptr i8, i8* %118, i64 %lsr.iv150
#   %uglygep156157 = bitcast i8* %uglygep156 to i64*
#   %.510.us40.us.prol = load i64, i64* %uglygep156157, align 8
#   %.14.i.us41.us.prol = sitofp i64 %.510.us40.us.prol to double
#   %.15.i.us42.us.prol = fadd double %trace.0.lcssa102, %.14.i.us41.us.prol
#   %scevgep152 = getelementptr i8, i8* %lsr.iv20, i64 %lsr.iv150
#   %scevgep152153 = bitcast i8* %scevgep152 to double*
#   store double %.15.i.us42.us.prol, double* %scevgep152153, align 8
#   %lsr.iv.next149 = add nsw i64 %lsr.iv148, -1
#   %lsr.iv.next151 = add nuw nsw i64 %lsr.iv150, 8
#   %prol.iter222.cmp = icmp eq i64 %14, %lsr.iv.next149
#   br i1 %prol.iter222.cmp, label %for.body.2.endif.endif.endif.us33.us.prol.loopexit.loopexit, label %for.body.2.endif.endif.endif.us33.us.prol, !llvm.loop !21
#
# for.body.2.endif.endif.endif.us33.us.prol.loopexit.loopexit: ; preds = %for.body.2.endif.endif.endif.us33.us.prol
#   %119 = add i64 %loop.index.231.us34.us.ph, -1
#   %120 = sub i64 %119, %lsr.iv.next149
#   %121 = sub i64 %loop.index.231.us34.us.ph, %lsr.iv.next149
#   br label %for.body.2.endif.endif.endif.us33.us.prol.loopexit
#
# for.body.2.endif.endif.endif.us33.us.prol.loopexit: ; preds = %for.body.2.endif.endif.endif.us33.us.prol.loopexit.loopexit, %for.body.2.endif.endif.endif.us33.us.preheader198
#   %loop.index.231.us34.us.lcssa.unr = phi i64 [ undef, %for.body.2.endif.endif.endif.us33.us.preheader198 ], [ %120, %for.body.2.endif.endif.endif.us33.us.prol.loopexit.loopexit ]
#   %loop.index.231.us34.us.unr = phi i64 [ %loop.index.231.us34.us.ph, %for.body.2.endif.endif.endif.us33.us.preheader198 ], [ %121, %for.body.2.endif.endif.endif.us33.us.prol.loopexit.loopexit ]
#   %122 = icmp ult i64 %116, 3
#   br i1 %122, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us33.us.preheader1
#
# for.body.2.endif.endif.endif.us33.us.preheader1:  ; preds = %for.body.2.endif.endif.endif.us33.us.prol.loopexit
#   %123 = add i64 %loop.index.231.us34.us.unr, -1
#   %scevgep161 = getelementptr i64, i64* %scevgep160, i64 %.505.us37.us
#   br label %for.body.2.endif.endif.endif.us33.us
#
# for.body.2.endif.endif.endif.us33.us:             ; preds = %for.body.2.endif.endif.endif.us33.us.preheader1, %for.body.2.endif.endif.endif.us33.us
#   %lsr.iv158 = phi i64 [ %123, %for.body.2.endif.endif.endif.us33.us.preheader1 ], [ %lsr.iv.next159, %for.body.2.endif.endif.endif.us33.us ]
#   %scevgep167 = getelementptr i64, i64* %scevgep161, i64 %lsr.iv158
#   %scevgep168 = getelementptr i64, i64* %scevgep167, i64 -2
#   %.510.us40.us = load i64, i64* %scevgep168, align 8
#   %.14.i.us41.us = sitofp i64 %.510.us40.us to double
#   %.15.i.us42.us = fadd double %trace.0.lcssa102, %.14.i.us41.us
#   %124 = shl i64 %lsr.iv158, 3
#   %scevgep169 = getelementptr i8, i8* %lsr.iv20, i64 %124
#   %scevgep169170 = bitcast i8* %scevgep169 to double*
#   %scevgep171 = getelementptr double, double* %scevgep169170, i64 1
#   store double %.15.i.us42.us, double* %scevgep171, align 8
#   %scevgep165 = getelementptr i64, i64* %scevgep161, i64 %lsr.iv158
#   %scevgep166 = getelementptr i64, i64* %scevgep165, i64 -1
#   %.510.us40.us.1 = load i64, i64* %scevgep166, align 8
#   %.14.i.us41.us.1 = sitofp i64 %.510.us40.us.1 to double
#   %.15.i.us42.us.1 = fadd double %trace.0.lcssa102, %.14.i.us41.us.1
#   %125 = shl i64 %lsr.iv158, 3
#   %scevgep178 = getelementptr i8, i8* %lsr.iv20, i64 %125
#   %scevgep178179 = bitcast i8* %scevgep178 to double*
#   %scevgep180 = getelementptr double, double* %scevgep178179, i64 2
#   store double %.15.i.us42.us.1, double* %scevgep180, align 8
#   %scevgep164 = getelementptr i64, i64* %scevgep161, i64 %lsr.iv158
#   %.510.us40.us.2 = load i64, i64* %scevgep164, align 8
#   %.14.i.us41.us.2 = sitofp i64 %.510.us40.us.2 to double
#   %.15.i.us42.us.2 = fadd double %trace.0.lcssa102, %.14.i.us41.us.2
#   %126 = shl i64 %lsr.iv158, 3
#   %scevgep175 = getelementptr i8, i8* %lsr.iv20, i64 %126
#   %scevgep175176 = bitcast i8* %scevgep175 to double*
#   %scevgep177 = getelementptr double, double* %scevgep175176, i64 3
#   store double %.15.i.us42.us.2, double* %scevgep177, align 8
#   %scevgep162 = getelementptr i64, i64* %scevgep161, i64 %lsr.iv158
#   %scevgep163 = getelementptr i64, i64* %scevgep162, i64 1
#   %.510.us40.us.3 = load i64, i64* %scevgep163, align 8
#   %.14.i.us41.us.3 = sitofp i64 %.510.us40.us.3 to double
#   %.15.i.us42.us.3 = fadd double %trace.0.lcssa102, %.14.i.us41.us.3
#   %127 = shl i64 %lsr.iv158, 3
#   %scevgep172 = getelementptr i8, i8* %lsr.iv20, i64 %127
#   %scevgep172173 = bitcast i8* %scevgep172 to double*
#   %scevgep174 = getelementptr double, double* %scevgep172173, i64 4
#   store double %.15.i.us42.us.3, double* %scevgep174, align 8
#   %lsr.iv.next159 = add i64 %lsr.iv158, 4
#   %128 = add i64 %15, %lsr.iv.next159
#   %exitcond93.3 = icmp eq i64 %128, -1
#   br i1 %exitcond93.3, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us33.us, !llvm.loop !22
#
# for.body.2.endif.endif.endif.lr.ph.split.for.body.2.endif.endif.endif.lr.ph.split.split_crit_edge.us: ; preds = %for.body.2.endif.endif.endif.lr.ph.for.body.2.endif.endif.endif.lr.ph.split_crit_edge.us
#   %129 = icmp ult i64 %6, 3
#   %.508.us57 = add i64 %.485.050.us, %.505.us37.us
#   br i1 %129, label %for.cond.2.for.end.2_crit_edge.us.loopexit199.unr-lcssa, label %for.body.2.endif.endif.endif.us54.preheader
#
# for.body.2.endif.endif.endif.us54.preheader:      ; preds = %for.body.2.endif.endif.endif.lr.ph.split.for.body.2.endif.endif.endif.lr.ph.split.split_crit_edge.us
#   br label %for.body.2.endif.endif.endif.us54
#
# for.body.2.endif.endif.endif.us.us.us:            ; preds = %for.body.2.endif.endif.endif.us.us.us.preheader3, %for.body.2.endif.endif.endif.us.us.us
#   %lsr.iv74 = phi i64 [ %63, %for.body.2.endif.endif.endif.us.us.us.preheader3 ], [ %lsr.iv.next75, %for.body.2.endif.endif.endif.us.us.us ]
#   %scevgep90 = getelementptr i64, i64* %lsr.iv68, i64 %lsr.iv74
#   %scevgep91 = getelementptr i64, i64* %scevgep90, i64 1
#   %.510.us.us.us = load i64, i64* %scevgep91, align 8
#   %.14.i.us.us.us = sitofp i64 %.510.us.us.us to double
#   %.15.i.us.us.us = fadd double %trace.0.lcssa102, %.14.i.us.us.us
#   %130 = shl i64 %lsr.iv74, 3
#   %scevgep79 = getelementptr i8, i8* %lsr.iv20, i64 %130
#   %scevgep7980 = bitcast i8* %scevgep79 to double*
#   %scevgep81 = getelementptr double, double* %scevgep7980, i64 1
#   store double %.15.i.us.us.us, double* %scevgep81, align 8
#   %scevgep92 = getelementptr i64, i64* %lsr.iv68, i64 %lsr.iv74
#   %scevgep93 = getelementptr i64, i64* %scevgep92, i64 2
#   %.510.us.us.us.1 = load i64, i64* %scevgep93, align 8
#   %.14.i.us.us.us.1 = sitofp i64 %.510.us.us.us.1 to double
#   %.15.i.us.us.us.1 = fadd double %trace.0.lcssa102, %.14.i.us.us.us.1
#   %131 = shl i64 %lsr.iv74, 3
#   %scevgep85 = getelementptr i8, i8* %lsr.iv20, i64 %131
#   %scevgep8586 = bitcast i8* %scevgep85 to double*
#   %scevgep87 = getelementptr double, double* %scevgep8586, i64 2
#   store double %.15.i.us.us.us.1, double* %scevgep87, align 8
#   %scevgep94 = getelementptr i64, i64* %lsr.iv68, i64 %lsr.iv74
#   %scevgep95 = getelementptr i64, i64* %scevgep94, i64 3
#   %.510.us.us.us.2 = load i64, i64* %scevgep95, align 8
#   %.14.i.us.us.us.2 = sitofp i64 %.510.us.us.us.2 to double
#   %.15.i.us.us.us.2 = fadd double %trace.0.lcssa102, %.14.i.us.us.us.2
#   %132 = shl i64 %lsr.iv74, 3
#   %scevgep76 = getelementptr i8, i8* %lsr.iv20, i64 %132
#   %scevgep7677 = bitcast i8* %scevgep76 to double*
#   %scevgep78 = getelementptr double, double* %scevgep7677, i64 3
#   store double %.15.i.us.us.us.2, double* %scevgep78, align 8
#   %scevgep88 = getelementptr i64, i64* %lsr.iv68, i64 %lsr.iv74
#   %scevgep89 = getelementptr i64, i64* %scevgep88, i64 4
#   %.510.us.us.us.3 = load i64, i64* %scevgep89, align 8
#   %.14.i.us.us.us.3 = sitofp i64 %.510.us.us.us.3 to double
#   %.15.i.us.us.us.3 = fadd double %trace.0.lcssa102, %.14.i.us.us.us.3
#   %133 = shl i64 %lsr.iv74, 3
#   %scevgep82 = getelementptr i8, i8* %lsr.iv20, i64 %133
#   %scevgep8283 = bitcast i8* %scevgep82 to double*
#   %scevgep84 = getelementptr double, double* %scevgep8283, i64 4
#   store double %.15.i.us.us.us.3, double* %scevgep84, align 8
#   %lsr.iv.next75 = add i64 %lsr.iv74, 4
#   %134 = add i64 %15, %lsr.iv.next75
#   %exitcond95.3 = icmp eq i64 %134, -1
#   br i1 %exitcond95.3, label %for.cond.2.for.end.2_crit_edge.us, label %for.body.2.endif.endif.endif.us.us.us, !llvm.loop !23
#
# for.body.2.endif.endif.endif.lr.ph.split.us.for.body.2.endif.endif.endif.lr.ph.split.us.split_crit_edge.us: ; preds = %for.body.2.endif.endif.endif.lr.ph.split.us.us
#   %135 = icmp ult i64 %6, 3
#   %.508.us.us71 = add i64 %.485.050.us, %.505.us.us
#   br i1 %135, label %for.cond.2.for.end.2_crit_edge.us.loopexit202.unr-lcssa, label %for.body.2.endif.endif.endif.us.us69.preheader
#
# for.body.2.endif.endif.endif.us.us69.preheader:   ; preds = %for.body.2.endif.endif.endif.lr.ph.split.us.for.body.2.endif.endif.endif.lr.ph.split.us.split_crit_edge.us
#   br label %for.body.2.endif.endif.endif.us.us69
#
# for.end.1:                                        ; preds = %for.cond.2.for.end.2_crit_edge.us, %for.cond.2.preheader.lr.ph, %B52.endif.endif.endif
#   tail call void @NRT_decref(i8* %arg.a.0)
#   %retptr.repack193 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr to i8**
#   store i8* %.441, i8** %retptr.repack193, align 8
#   %retptr.repack4 = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 1
#   store i8* null, i8** %retptr.repack4, align 8
#   %retptr.repack6 = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 2
#   store i64 %.427, i64* %retptr.repack6, align 8
#   %retptr.repack8 = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 3
#   store i64 8, i64* %retptr.repack8, align 8
#   %retptr.repack10 = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 4
#   %136 = bitcast double** %retptr.repack10 to i8**
#   store i8* %.6.i, i8** %136, align 8
#   %retptr.repack12.repack = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 5, i64 0
#   store i64 %arg.a.5.0, i64* %retptr.repack12.repack, align 8
#   %retptr.repack12.repack18 = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 5, i64 1
#   store i64 %arg.a.5.1, i64* %retptr.repack12.repack18, align 8
#   %retptr.repack14.repack = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 6, i64 0
#   store i64 %.430, i64* %retptr.repack14.repack, align 8
#   %retptr.repack14.repack16 = getelementptr inbounds { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %retptr, i64 0, i32 6, i64 1
#   store i64 8, i64* %retptr.repack14.repack16, align 8
#   ret i32 0
#
# B88.i.1:                                          ; preds = %B24, %entry
#   %trace.0.lcssa102 = phi double [ 0.000000e+00, %entry ], [ %.334, %B24 ]
#   %.426 = tail call { i64, i1 } @llvm.smul.with.overflow.i64(i64 %arg.a.5.0, i64 %arg.a.5.1)
#   %.427 = extractvalue { i64, i1 } %.426, 0
#   %.428 = extractvalue { i64, i1 } %.426, 1
#   %.431 = tail call { i64, i1 } @llvm.smul.with.overflow.i64(i64 %.427, i64 8)
#   %.433 = extractvalue { i64, i1 } %.431, 1
#   %.434 = or i1 %.428, %.433
#   br i1 %.434, label %B52.endif.endif.if, label %B52.endif.endif.endif, !prof !24
# }
#
# ; Function Attrs: nounwind readonly
# declare double @tanh(double) local_unnamed_addr #0
#
# ; Function Attrs: nounwind readnone speculatable
# declare { i64, i1 } @llvm.smul.with.overflow.i64(i64, i64) #1
#
# declare noalias i8* @NRT_MemInfo_alloc_safe_aligned(i64, i32) local_unnamed_addr
#
# define i8* @"_ZN7cpython8__main__11go_slow$241E5ArrayIxLi2E1C7mutable7alignedE"(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([8 x i8], [8 x i8]* @.const.go_slow, i64 0, i64 0), i64 1, i64 1, i8** nonnull %.5)
#   %.7 = icmp eq i32 %.6, 0
#   %.21 = alloca { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }, align 8
#   %.45 = alloca { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, align 8
#   %0 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 %0, i8 0, i64 72, i1 false)
#   %excinfo = alloca { i8*, i32 }*, align 8
#   %1 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 %1, i8 0, i64 72, i1 false)
#   store { i8*, i32 }* null, { i8*, i32 }** %excinfo, align 8
#   %.95 = alloca { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }, align 8
#   %2 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 %2, i8 0, i64 72, i1 false)
#   br i1 %.7, label %entry.if, label %entry.endif, !prof !24
#
# entry.if:                                         ; preds = %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.if.if, %entry.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.thread, %entry
#   ret i8* null
#
# entry.endif:                                      ; preds = %entry
#   %.11 = load i8*, i8** @"_ZN08NumbaEnv8__main__11go_slow$241E5ArrayIxLi2E1C7mutable7alignedE", align 8
#   %.16 = icmp eq i8* %.11, null
#   br i1 %.16, label %entry.endif.if, label %entry.endif.endif, !prof !24
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @".const.missing Environment", i64 0, i64 0))
#   ret i8* null
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.20 = load i8*, i8** %.5, align 8
#   %.24 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %3 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 %3, i8 0, i64 72, i1 false)
#   %.25 = call i32 @NRT_adapt_ndarray_from_python(i8* %.20, i8* nonnull %.24)
#   %4 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr = getelementptr i8, i8* %4, i64 24
#   %5 = bitcast i8* %sunkaddr to i64*
#   %.29 = load i64, i64* %5, align 8
#   %.30 = icmp ne i64 %.29, 8
#   %.31 = icmp ne i32 %.25, 0
#   %.32 = or i1 %.31, %.30
#   br i1 %.32, label %entry.endif.endif.endif.thread, label %entry.endif.endif.endif.endif, !prof !24
#
# entry.endif.endif.endif.thread:                   ; preds = %entry.endif.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_TypeError, i8* getelementptr inbounds ([89 x i8], [89 x i8]* @".const.can't unbox array from PyObject into native value.  The object maybe of a different type", i64 0, i64 0))
#   br label %entry.if
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif
#   %6 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8**
#   %.36.fca.0.load = load i8*, i8** %6, align 8
#   %7 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr2 = getelementptr i8, i8* %7, i64 8
#   %8 = bitcast i8* %sunkaddr2 to i8**
#   %.36.fca.1.load = load i8*, i8** %8, align 8
#   %9 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr3 = getelementptr i8, i8* %9, i64 16
#   %10 = bitcast i8* %sunkaddr3 to i64*
#   %.36.fca.2.load = load i64, i64* %10, align 8
#   %11 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr4 = getelementptr i8, i8* %11, i64 32
#   %12 = bitcast i8* %sunkaddr4 to i64**
#   %.36.fca.4.load = load i64*, i64** %12, align 8
#   %13 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr5 = getelementptr i8, i8* %13, i64 40
#   %14 = bitcast i8* %sunkaddr5 to i64*
#   %.36.fca.5.0.load = load i64, i64* %14, align 8
#   %15 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr6 = getelementptr i8, i8* %15, i64 48
#   %16 = bitcast i8* %sunkaddr6 to i64*
#   %.36.fca.5.1.load = load i64, i64* %16, align 8
#   %17 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr7 = getelementptr i8, i8* %17, i64 56
#   %18 = bitcast i8* %sunkaddr7 to i64*
#   %.36.fca.6.0.load = load i64, i64* %18, align 8
#   %19 = bitcast { i8*, i8*, i64, i64, i64*, [2 x i64], [2 x i64] }* %.21 to i8*
#   %sunkaddr8 = getelementptr i8, i8* %19, i64 64
#   %20 = bitcast i8* %sunkaddr8 to i64*
#   %.36.fca.6.1.load = load i64, i64* %20, align 8
#   %21 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 %21, i8 0, i64 72, i1 false)
#   %.53 = call i32 @"_ZN8__main__11go_slow$241E5ArrayIxLi2E1C7mutable7alignedE"({ i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* nonnull %.45, { i8*, i32 }** nonnull %excinfo, i8* %.36.fca.0.load, i8* %.36.fca.1.load, i64 %.36.fca.2.load, i64 8, i64* %.36.fca.4.load, i64 %.36.fca.5.0.load, i64 %.36.fca.5.1.load, i64 %.36.fca.6.0.load, i64 %.36.fca.6.1.load)
#   %.54 = load { i8*, i32 }*, { i8*, i32 }** %excinfo, align 8
#   %22 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i64*
#   %.63.fca.0.load3 = load i64, i64* %22, align 8
#   %23 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr9 = getelementptr i8, i8* %23, i64 8
#   %24 = bitcast i8* %sunkaddr9 to i64*
#   %.63.fca.1.load2 = load i64, i64* %24, align 8
#   %25 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr10 = getelementptr i8, i8* %25, i64 16
#   %26 = bitcast i8* %sunkaddr10 to i64*
#   %.63.fca.2.load = load i64, i64* %26, align 8
#   %27 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr11 = getelementptr i8, i8* %27, i64 24
#   %28 = bitcast i8* %sunkaddr11 to i64*
#   %.63.fca.3.load = load i64, i64* %28, align 8
#   %29 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr12 = getelementptr i8, i8* %29, i64 32
#   %30 = bitcast i8* %sunkaddr12 to i64*
#   %.63.fca.4.load1 = load i64, i64* %30, align 8
#   %31 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr13 = getelementptr i8, i8* %31, i64 40
#   %32 = bitcast i8* %sunkaddr13 to i64*
#   %.63.fca.5.0.load = load i64, i64* %32, align 8
#   %33 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr14 = getelementptr i8, i8* %33, i64 48
#   %34 = bitcast i8* %sunkaddr14 to i64*
#   %.63.fca.5.1.load = load i64, i64* %34, align 8
#   %35 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr15 = getelementptr i8, i8* %35, i64 56
#   %36 = bitcast i8* %sunkaddr15 to i64*
#   %.63.fca.6.0.load = load i64, i64* %36, align 8
#   %37 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.45 to i8*
#   %sunkaddr16 = getelementptr i8, i8* %37, i64 64
#   %38 = bitcast i8* %sunkaddr16 to i64*
#   %.63.fca.6.1.load = load i64, i64* %38, align 8
#   call void @NRT_decref(i8* %.36.fca.0.load)
#   switch i32 %.53, label %entry.endif.endif.endif.endif.endif [
#     i32 -2, label %entry.endif.endif.endif.endif.if.if
#     i32 0, label %entry.endif.endif.endif.endif.if.endif
#   ]
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif
#   %.61 = icmp sgt i32 %.53, 0
#   br i1 %.61, label %entry.endif.endif.endif.endif.endif.if, label %entry.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.if.if:              ; preds = %entry.endif.endif.endif.endif
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   ret i8* @_Py_NoneStruct
#
# entry.endif.endif.endif.endif.if.endif:           ; preds = %entry.endif.endif.endif.endif
#   %sunkaddr17 = getelementptr i8, i8* %.11, i64 24
#   %39 = bitcast i8* %sunkaddr17 to i8**
#   %.93 = load i8*, i8** %39, align 8
#   %.94 = call i8* @PyList_GetItem(i8* %.93, i64 0)
#   %40 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i64*
#   store i64 %.63.fca.0.load3, i64* %40, align 8
#   %41 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr18 = getelementptr i8, i8* %41, i64 8
#   %42 = bitcast i8* %sunkaddr18 to i64*
#   store i64 %.63.fca.1.load2, i64* %42, align 8
#   %43 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr19 = getelementptr i8, i8* %43, i64 16
#   %44 = bitcast i8* %sunkaddr19 to i64*
#   store i64 %.63.fca.2.load, i64* %44, align 8
#   %45 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr20 = getelementptr i8, i8* %45, i64 24
#   %46 = bitcast i8* %sunkaddr20 to i64*
#   store i64 %.63.fca.3.load, i64* %46, align 8
#   %47 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr21 = getelementptr i8, i8* %47, i64 32
#   %48 = bitcast i8* %sunkaddr21 to i64*
#   store i64 %.63.fca.4.load1, i64* %48, align 8
#   %49 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr22 = getelementptr i8, i8* %49, i64 40
#   %50 = bitcast i8* %sunkaddr22 to i64*
#   store i64 %.63.fca.5.0.load, i64* %50, align 8
#   %51 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr23 = getelementptr i8, i8* %51, i64 48
#   %52 = bitcast i8* %sunkaddr23 to i64*
#   store i64 %.63.fca.5.1.load, i64* %52, align 8
#   %53 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr24 = getelementptr i8, i8* %53, i64 56
#   %54 = bitcast i8* %sunkaddr24 to i64*
#   store i64 %.63.fca.6.0.load, i64* %54, align 8
#   %55 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %sunkaddr25 = getelementptr i8, i8* %55, i64 64
#   %56 = bitcast i8* %sunkaddr25 to i64*
#   store i64 %.63.fca.6.1.load, i64* %56, align 8
#   %.98 = bitcast { i8*, i8*, i64, i64, double*, [2 x i64], [2 x i64] }* %.95 to i8*
#   %.99 = call i8* @NRT_adapt_ndarray_to_python(i8* nonnull %.98, i32 2, i32 1, i8* %.94)
#   ret i8* %.99
#
# entry.endif.endif.endif.endif.endif.if:           ; preds = %entry.endif.endif.endif.endif.endif
#   call void @PyErr_Clear()
#   %.104 = load { i8*, i32 }, { i8*, i32 }* %.54, align 8
#   %.105 = extractvalue { i8*, i32 } %.104, 0
#   %.107 = extractvalue { i8*, i32 } %.104, 1
#   %.108 = call i8* @numba_unpickle(i8* %.105, i32 %.107)
#   %.109 = icmp eq i8* %.108, null
#   br i1 %.109, label %entry.if, label %entry.endif.endif.endif.endif.endif.if.if, !prof !24
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   switch i32 %.53, label %entry.endif.endif.endif.endif.endif.endif.endif.endif [
#     i32 -3, label %entry.endif.endif.endif.endif.endif.endif.if
#     i32 -1, label %entry.if
#   ]
#
# entry.endif.endif.endif.endif.endif.if.if:        ; preds = %entry.endif.endif.endif.endif.endif.if
#   call void @numba_do_raise(i8* nonnull %.108)
#   br label %entry.if
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   call void @PyErr_SetNone(i8* nonnull @PyExc_StopIteration)
#   br label %entry.if
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_SystemError, i8* getelementptr inbounds ([43 x i8], [43 x i8]* @".const.unknown error when calling native function", i64 0, i64 0))
#   br label %entry.if
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i32 @NRT_adapt_ndarray_from_python(i8* nocapture, i8* nocapture) local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# declare i8* @PyList_GetItem(i8*, i64) local_unnamed_addr
#
# declare i8* @NRT_adapt_ndarray_to_python(i8* nocapture, i32, i32, i8*) local_unnamed_addr
#
# declare void @PyErr_Clear() local_unnamed_addr
#
# declare i8* @numba_unpickle(i8*, i32) local_unnamed_addr
#
# declare void @numba_do_raise(i8*) local_unnamed_addr
#
# declare void @PyErr_SetNone(i8*) local_unnamed_addr
#
# ; Function Attrs: noinline norecurse nounwind
# define linkonce_odr void @NRT_incref(i8* %.1) local_unnamed_addr #2 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !24
#
# .3.if:                                            ; preds = %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   %.7 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw add i64* %.7, i64 1 monotonic
#   ret void
# }
#
# ; Function Attrs: noinline
# define linkonce_odr void @NRT_decref(i8* %.1) local_unnamed_addr #3 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !24
#
# .3.if:                                            ; preds = %.3.endif, %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw sub i64* %.8, i64 1 monotonic
#   %.10 = icmp eq i64 %.4.i, 1
#   br i1 %.10, label %.3.endif.if, label %.3.if, !prof !24
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   tail call void @NRT_MemInfo_call_dtor(i8* nonnull %.1)
#   ret void
# }
#
# declare void @NRT_MemInfo_call_dtor(i8*) local_unnamed_addr
#
# ; Function Attrs: argmemonly nounwind
# declare void @llvm.memset.p0i8.i64(i8* nocapture writeonly, i8, i64, i1) #4
#
# ; Function Attrs: nounwind
# declare void @llvm.stackprotector(i8*, i8**) #5
#
# attributes #0 = { nounwind readonly }
# attributes #1 = { nounwind readnone speculatable }
# attributes #2 = { noinline norecurse nounwind }
# attributes #3 = { noinline }
# attributes #4 = { argmemonly nounwind }
# attributes #5 = { nounwind }
#
# !0 = distinct !{!0, !1}
# !1 = !{!"llvm.loop.isvectorized", i32 1}
# !2 = distinct !{!2, !3}
# !3 = !{!"llvm.loop.unroll.disable"}
# !4 = distinct !{!4, !3}
# !5 = distinct !{!5, !1}
# !6 = distinct !{!6, !3}
# !7 = !{!8}
# !8 = distinct !{!8, !9}
# !9 = distinct !{!9, !"LVerDomain"}
# !10 = !{!11}
# !11 = distinct !{!11, !9}
# !12 = distinct !{!12, !1}
# !13 = distinct !{!13, !3}
# !14 = !{!15}
# !15 = distinct !{!15, !16}
# !16 = distinct !{!16, !"LVerDomain"}
# !17 = !{!18}
# !18 = distinct !{!18, !16}
# !19 = distinct !{!19, !1}
# !20 = distinct !{!20, !3}
# !21 = distinct !{!21, !3}
# !22 = distinct !{!22, !1}
# !23 = distinct !{!23, !1}
# !24 = !{!"branch_weights", i32 1, i32 99}
